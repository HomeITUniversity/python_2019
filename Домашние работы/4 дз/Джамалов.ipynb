# %% [markdown]
# # Задача 1
#
# Дан список сотрудников банка.
# names = [«Иван», «Марина», «Виталий», «Александр»]
# lastnames = [«Салтыков», «Иванова», «Жученко», «Петров»]
# middlenames = [«Романович», «Ивановна», «Даниилович», «Евгеньевич»]
# ages = [24, 25, 30, 28]
# Нужно составить словарь, в котором ключом будет ФИО, а значением возраст.

# %% [markdown]
# Мягкий дедлайн: 9 октрября.
#
# Жеcткий дедлайн 16 октрября.

# %%
names = ['Иван', 'Марина', 'Виталий', 'Александр']
lastnames = ['Салтыков', 'Иванова', 'Жученко', 'Петров']
middlenames = ['Романович', 'Ивановна', 'Даниилович', 'Евгеньевич']
ages = [24, 25, 30, 28]
result_dict = {}

# ваш код тут
for a,b,c,d in zip(lastnames,names,middlenames,ages):
    FIO=a+" "+b+" "+c
    result_dict [FIO]=d
print("Cловарь:\n",result_dict)

true_result_dict = {
    'Салтыков Иван Романович': 24, 
    'Иванова Марина Ивановна': 25, 
    'Жученко Виталий Даниилович': 30, 
    'Петров Александр Евгеньевич': 28
}
assert result_dict == true_result_dict
print("OK")

#если воникает эта ошибка "AssertionError" значит вы решили не верно, 
#иначе вы решили все верно
# Out:
# Cловарь:
#  {'Салтыков Иван Романович': 24, 'Иванова Марина Ивановна': 25, 'Жученко Виталий Даниилович': 30, 'Петров Александр Евгеньевич': 28}
# OK

# %% [markdown]
# # Задача 2
# Дан текст. Найти частоту встречания символов в тексте и оформить это как словарь. Где символ – ключ, частота встречания – значения. Спец. Символы исключить.

# %%
s = "А из города уже выступало неприятельское войско, гремя в литавры и трубы. Подбоченясь, выезжали паны, окруженные несметными слугами. И стали они наступать тесно на казацкие таборы, грозя, нацеливаясь пищалями, сверкая очами и блеща медными доспехами. Дымом затянуло все поле, а запорожцы все палили, не переводя дух."
result_dict = {}

# ваш код тут
aa=[';','!',',','.','$','-',':',' ']
for i in range (len(aa)):
    s=s.replace(aa[i],'')
s=s.lower()
for i in s:
    if(result_dict.get(i,0)==0):
        result_dict[i]=s.count(i)
print("Словарь:\n",result_dict)

true_result_dict = {'а': 25, 'и': 20, 'з': 6, 'г': 4, 'о': 21, 'р': 11, 'д': 7, 'у': 8, 'ж': 4, 'е': 24, 'в': 10, 'ы': 11, 'с': 14, 'т': 11, 'п': 11, 'л': 13, 'н': 15, 'я': 9, 'ь': 4, 'к': 6, 'й': 1, 'м': 11, 'б': 4, 'ч': 2, 'ц': 3, 'щ': 2, 'х': 2}

assert result_dict == true_result_dict
print("OK")
# Out:
# Словарь:
#  {'а': 25, 'и': 20, 'з': 6, 'г': 4, 'о': 21, 'р': 11, 'д': 7, 'у': 8, 'ж': 4, 'е': 24, 'в': 10, 'ы': 11, 'с': 14, 'т': 11, 'п': 11, 'л': 13, 'н': 15, 'я': 9, 'ь': 4, 'к': 6, 'й': 1, 'м': 11, 'б': 4, 'ч': 2, 'ц': 3, 'щ': 2, 'х': 2}
# OK

# %% [markdown]
# # Задача 3
# Составить словарь из двух ключей "unique", "nonunique". В первый ключ положить список уникальных слов, во второй не уникальных.

# %%
s = """Это слово, которое я в детстве постоянно слышал от моей мамы.
Мама произносила это слово так нежно и так серьезно, словно оно обозначало что-то столь важное, неотъемлемое.
Я любил это слово, из-за этого я делал все, чтоб его услышать как можно чаще.
Я вырос. Я понял, что это слово не представляет из себя чего-то сверхъестественного, не обозначает оно какое-то божество и произнести его можно по разному.
Это слово самое обычное... но в то же время самое сильное.
Это слово ~ Спасибо."""
result_dict = {}

# ваш код тут
b=[]
w=[]
aa=[';','!',',','.','$',':','~']
for i in range (len(aa)):
    s=s.replace(aa[i],'')
s=(s.lower()).split()
for i in s:
    if s.count(i)==1:
        w.append(i)
    if s.count(i)!=1 and b.count(i)<1:
        b.append(i)

result_dict["unique"]=w
result_dict["nonunique"]=b

print("Результат:\n",result_dict)

true_result_dict = {
    'unique': ['которое', 'детстве', 'постоянно', 'слышал', 'от', 'моей', 'мамы', 'мама', 'произносила', 'нежно', 'серьезно', 'словно', 'обозначало', 'что-то', 'столь', 'важное', 'неотъемлемое', 'любил', 'из-за', 'этого', 'делал', 'все', 'чтоб', 'услышать', 'как', 'чаще', 'вырос', 'понял', 'что', 'представляет', 'из', 'себя', 'чего-то', 'сверхъестественного', 'обозначает', 'какое-то', 'божество', 'произнести', 'по', 'разному', 'обычное', 'но', 'то', 'же', 'время', 'сильное', 'спасибо'], 
    'nonunique': ['это', 'слово', 'я', 'в', 'так', 'и', 'оно', 'его', 'можно', 'не', 'самое']
}

assert result_dict == true_result_dict
print("OK")
# Out:
# Результат:
#  {'unique': ['которое', 'детстве', 'постоянно', 'слышал', 'от', 'моей', 'мамы', 'мама', 'произносила', 'нежно', 'серьезно', 'словно', 'обозначало', 'что-то', 'столь', 'важное', 'неотъемлемое', 'любил', 'из-за', 'этого', 'делал', 'все', 'чтоб', 'услышать', 'как', 'чаще', 'вырос', 'понял', 'что', 'представляет', 'из', 'себя', 'чего-то', 'сверхъестественного', 'обозначает', 'какое-то', 'божество', 'произнести', 'по', 'разному', 'обычное', 'но', 'то', 'же', 'время', 'сильное', 'спасибо'], 'nonunique': ['это', 'слово', 'я', 'в', 'так', 'и', 'оно', 'его', 'можно', 'не', 'самое']}
# OK

# %% [markdown]
# # Задача 4
#
# Маша и Аня работают в отделе продаж нашего банка и продают Кредиты наличными. <br>
# Оформленные ими кредиты представлены в соответствующих словарях (сумма кредита, ставка, срок в годах)<br>
# Среди клиентов Маши и Ани найти клиентов и вывести на экран, у которых:<br>
# •	Совпадает ставка<br>
# •	Совпадает сумма кредита<br>
# •	Совпадает срок выплаты<br>
# •	Не совпадает сумма, но совпадает срок выплаты<br>
# •	Совпадает процентная ставка, но не совпадает сумма кредита.<br>
# Условие может, как выполниться, так и не выполниться (такое пересечение может быть пустым)<br>
#
# Выводить ВСЕ значения которые имеют совпадения.

# %%
masha_credits = {
        'Салтыков Иван': {
        'credit': 80000,
        'percent': 22.5,
        'period': 3
    },
        'Иванова Марина': {
        'credit': 240000,
        'percent': 20.8,
        'period': 5
    },
        'Жученко Виталий': {
        'credit': 35000,
        'percent': 19.4,
        'period': 2
    },
        'Петров Александр': {
        'credit': 100000,
        'percent': 27.9,
        'period': 3
    },
        'Краснов Антон': {
        'credit': 10000,
        'percent': 55.2,
        'period': 1
    },
        'Полено Елена': {
        'credit': 330000,
        'percent': 4.0,
        'period': 1
    },
}

ann_credits = {
        'Букин Геннадий': {
        'credit': 1000,
        'percent': 55.2,
        'period': 20
    },
        'Антонов Юрий': {
        'credit': 20000,
        'percent': 20.8,
        'period': 4
    },
        'Трененков Виталий': {
        'credit': 35000,
        'percent': 20.1,
        'period': 1
    },
        'Самоваров Павел': {
        'credit': 100000,
        'percent': 27.9,
        'period': 2
    },
        'Самсонов Владимир': {
        'credit': 76000,
        'percent': 11.9,
        'period': 4
    },
        'Антонина Антонина': {
        'credit': 1100000,
        'percent': 4.0,
        'period': 5
    },
        'Колованов Ярослав': {
        'credit': 25000,
        'percent': 22.2,
        'period': 2
    },
        'Чайкина Наталья': {
        'credit': 330000,
        'percent': 18.9,
        'period': 3
    },
}

# ваше решение тут
s=[]
j=[]
q=''
percent=''
period=''
h=[]
for i in masha_credits:
    for x in ann_credits:
        if masha_credits[i]['credit']==ann_credits[x]['credit'] and i!=x:
            if s.count(i)<1:
                s.append(i)
            s.append(x)
            q=ann_credits[x]['credit']
    if s!=[]:
        print("Совпадает сумма кредита:", q, "\n", s)
        s.clear()
print("______________________________")
for i in masha_credits:
    for x in ann_credits:
        if masha_credits[i]['percent']==ann_credits[x]['percent'] and i!=x:
            if j.count(i)<1:
                j.append(i)
            j.append(x)
            percent=ann_credits[x]['percent']
    if j != []:
        print("Совпадает ставка:", percent, "\n", j)
        j.clear()
print("______________________________")
for i in masha_credits:
    for x in ann_credits:
        if masha_credits[i]['period']==ann_credits[x]['period'] and i!=x:
            if h.count(i)<1:
                h.append(i)
            h.append(x)
            period=ann_credits[x]['period']
    if h!=[]:
        print("Совпадает срок выплаты:", period, "\n", h)
        h.clear()
print("______________________________")
for i in masha_credits:
    for x in ann_credits:
        if masha_credits[i]['credit']!=ann_credits[x]['credit'] and masha_credits[i]['period'] == ann_credits[x]['period'] and i != x:
            if h.count(i) < 1:
                h.append(i)
            h.append(x)
            period = ann_credits[x]['period']
    if h!=[]:
        print("Не совпадает сумма, но совпадает срок выплаты:",masha_credits[i]['period'],"\n", h)
        h.clear()
print("______________________________")
for i in masha_credits:
    for x in ann_credits:
        if masha_credits[i]['credit']!=ann_credits[x]['credit'] and masha_credits[i]['percent']==ann_credits[x]['percent'] and i!=x:
            if j.count(i)<1:
                j.append(i)
            j.append(x)
            percent=ann_credits[x]['percent']
    if j != []:
        print("Совпадает процентная ставка",masha_credits[i]['percent'],", но не совпадает сумма кредита:","\n", j)
        j.clear()
print("______________________________")
# Out:
# Совпадает сумма кредита: 35000
#  ['Жученко Виталий', 'Трененков Виталий']
# Совпадает сумма кредита: 100000
#  ['Петров Александр', 'Самоваров Павел']
# Совпадает сумма кредита: 330000
#  ['Полено Елена', 'Чайкина Наталья']
# ______________________________
# Совпадает ставка: 20.8
#  ['Иванова Марина', 'Антонов Юрий']
# Совпадает ставка: 27.9
#  ['Петров Александр', 'Самоваров Павел']
# Совпадает ставка: 55.2
#  ['Краснов Антон', 'Букин Геннадий']
# Совпадает ставка: 4.0
#  ['Полено Елена', 'Антонина Антонина']
# ______________________________
# Совпадает срок выплаты: 3
#  ['Салтыков Иван', 'Чайкина Наталья']
# Совпадает срок выплаты: 5
#  ['Иванова Марина', 'Антонина Антонина']
# Совпадает срок выплаты: 2
#  ['Жученко Виталий', 'Самоваров Павел', 'Колованов Ярослав']
# Совпадает срок выплаты: 3
#  ['Петров Александр', 'Чайкина Наталья']
# Совпадает срок выплаты: 1
#  ['Краснов Антон', 'Трененков Виталий']
# Совпадает срок выплаты: 1
#  ['Полено Елена', 'Трененков Виталий']
# ______________________________
# Не совпадает сумма, но совпадает срок выплаты: 3
#  ['Салтыков Иван', 'Чайкина Наталья']
# Не совпадает сумма, но совпадает срок выплаты: 5
#  ['Иванова Марина', 'Антонина Антонина']
# Не совпадает сумма, но совпадает срок выплаты: 2
#  ['Жученко Виталий', 'Самоваров Павел', 'Колованов Ярослав']
# Не совпадает сумма, но совпадает срок выплаты: 3
#  ['Петров Александр', 'Чайкина Наталья']
# Не совпадает сумма, но совпадает срок выплаты: 1
#  ['Краснов Антон', 'Трененков Виталий']
# Не совпадает сумма, но совпадает срок выплаты: 1
#  ['Полено Елена', 'Трененков Виталий']
# ______________________________
# Совпадает процентная ставка 20.8 , но не совпадает сумма кредита:
#  ['Иванова Марина', 'Антонов Юрий']
# Совпадает процентная ставка 55.2 , но не совпадает сумма кредита:
#  ['Краснов Антон', 'Букин Геннадий']
# Совпадает процентная ставка 4.0 , но не совпадает сумма кредита:
#  ['Полено Елена', 'Антонина Антонина']
# ______________________________

# %% [markdown]
# # Задача 5
# Суть задачи в том, чтобы из англо-латинского словаря сделать латино-английский.
#
# Входные данные:<br>
# Даны строки (необходимо представить в виде словаря)
#
# apple - malum, pomum, popula<br>
# fruit - baca, bacca, popum<br>
# punishment - malum, multa<br>
#
# Выходные данные:<br>
# baca - fruit<br>
# bacca - fruit<br>
# malum - apple, punishment<br>
# multa - punishment<br>
# pomum - apple<br>
# popula - apple<br>
# popum - fruit<br>

# %%
# Для apple и punishment указано одинаковое слово
dict_={'apple':'malum, pomum, popula','fruit':'baca, bacca, popum', 'punishment' :'malum, multa'}

a=input("Введите слово: ")
b=0
for x,y in zip(dict_.keys(),dict_.values()):
    if a in y:
      print(a,'-',x)
      b=1
if(b==0):
  print("Перевод не найден =(")
# Out:
# Введите слово: popum
# popum - fruit
