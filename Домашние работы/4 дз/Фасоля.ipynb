# %% [markdown]
# # Задача 1
#
# Дан список сотрудников банка.
# names = [«Иван», «Марина», «Виталий», «Александр»]
# lastnames = [«Салтыков», «Иванова», «Жученко», «Петров»]
# middlenames = [«Романович», «Ивановна», «Даниилович», «Евгеньевич»]
# ages = [24, 25, 30, 28]
# Нужно составить словарь, в котором ключом будет ФИО, а значением возраст.

# %% [markdown]
# Мягкий дедлайн: 9 октрября.
#
# Жеcткий дедлайн 16 октрября.

# %%
names = ['Иван', 'Марина', 'Виталий', 'Александр']
lastnames = ['Салтыков', 'Иванова', 'Жученко', 'Петров']
middlenames = ['Романович', 'Ивановна', 'Даниилович', 'Евгеньевич']
ages = [24, 25, 30, 28]
result_dict = {}

# ваш код тут
s = str()
fio = list()

for l, n, m,  in zip(lastnames, names, middlenames):
    s = l + " " + n + " " + m
    fio.append(s)

for  f, a in zip(fio, ages):
    result_dict[f] = a
    
print(result_dict)

true_result_dict = {
    'Салтыков Иван Романович': 24, 
    'Иванова Марина Ивановна': 25, 
    'Жученко Виталий Даниилович': 30, 
    'Петров Александр Евгеньевич': 28
}
assert result_dict == true_result_dict
print("OK")

#если воникает эта ошибка "AssertionError" значит вы решили не верно, 
#иначе вы решили все верно
# Out:
# {'Салтыков Иван Романович': 24, 'Иванова Марина Ивановна': 25, 'Жученко Виталий Даниилович': 30, 'Петров Александр Евгеньевич': 28}
# OK

# %% [markdown]
# # Задача 2
# Дан текст. Найти частоту встречания символов в тексте и оформить это как словарь. Где символ – ключ, частота встречания – значения. Спец. Символы исключить.

# %%
s = "А из города уже выступало неприятельское войско, гремя в литавры и трубы. Подбоченясь, выезжали паны, окруженные несметными слугами. И стали они наступать тесно на казацкие таборы, грозя, нацеливаясь пищалями, сверкая очами и блеща медными доспехами. Дымом затянуло все поле, а запорожцы все палили, не переводя дух."
result_dict = {}

# ваш код тут
s2 = []
s = s.lower()

for i in s:
  if i.isalpha():
     s2.append(i)
  else:
     continue

for element in s2:
    result_dict[element] = result_dict.get(element, 0) + 1      
      
print(result_dict)      

true_result_dict = {'а': 25, 'и': 20, 'з': 6, 'г': 4, 'о': 21, 'р': 11, 'д': 7, 'у': 8, 'ж': 4, 'е': 24, 'в': 10, 'ы': 11, 'с': 14, 'т': 11, 'п': 11, 'л': 13, 'н': 15, 'я': 9, 'ь': 4, 'к': 6, 'й': 1, 'м': 11, 'б': 4, 'ч': 2, 'ц': 3, 'щ': 2, 'х': 2}

assert result_dict == true_result_dict
print("OK")
# Out:
# {'а': 25, 'и': 20, 'з': 6, 'г': 4, 'о': 21, 'р': 11, 'д': 7, 'у': 8, 'ж': 4, 'е': 24, 'в': 10, 'ы': 11, 'с': 14, 'т': 11, 'п': 11, 'л': 13, 'н': 15, 'я': 9, 'ь': 4, 'к': 6, 'й': 1, 'м': 11, 'б': 4, 'ч': 2, 'ц': 3, 'щ': 2, 'х': 2}
# OK

# %% [markdown]
# # Задача 3
# Составить словарь из двух ключей "unique", "nonunique". В первый ключ положить список уникальных слов, во второй не уникальных.

# %%
s = """Это слово, которое я в детстве постоянно слышал от моей мамы.
Мама произносила это слово так нежно и так серьезно, словно оно обозначало что-то столь важное, неотъемлемое.
Я любил это слово, из-за этого я делал все, чтоб его услышать как можно чаще.
Я вырос. Я понял, что это слово не представляет из себя чего-то сверхъестественного, не обозначает оно какое-то божество и произнести его можно по разному.
Это слово самое обычное... но в то же время самое сильное.
Это слово ~ Спасибо."""
result_dict = {}

# ваш код тут
s2 = str()
s3 = str()
s4 = []
s5 = []
unique =[]
nonunique = []
dct = {}

s = s.lower()

for i in s:
  if i.isalpha() or i.isspace() or i == "-" :
     s2 += i
  else:
     continue
      
for i in s2:
  if i == "\n":
     s3 += " "
  else:
     s3 += i
    
s4 = s3.split(" ")

for i in s4:
  if i == "" or i == " " or i == "-" :
     continue
  else:
     s5.append(i)    

# for i in set(s5):
#     unique.append(i)

for element in s5:
    dct[element] = dct.get(element, 0) + 1

for key, val in dct.items():
    if val != 1:    
        nonunique.append(key)
    else:
        unique.append(key)
        
result_dict["unique"] = unique 
result_dict["nonunique"] = nonunique

print(result_dict)

true_result_dict = {
    'unique': ['которое', 'детстве', 'постоянно', 'слышал', 'от', 'моей', 'мамы', 'мама', 'произносила', 'нежно', 'серьезно', 'словно', 'обозначало', 'что-то', 'столь', 'важное', 'неотъемлемое', 'любил', 'из-за', 'этого', 'делал', 'все', 'чтоб', 'услышать', 'как', 'чаще', 'вырос', 'понял', 'что', 'представляет', 'из', 'себя', 'чего-то', 'сверхъестественного', 'обозначает', 'какое-то', 'божество', 'произнести', 'по', 'разному', 'обычное', 'но', 'то', 'же', 'время', 'сильное', 'спасибо'], 
    'nonunique': ['это', 'слово', 'я', 'в', 'так', 'и', 'оно', 'его', 'можно', 'не', 'самое']
}

assert result_dict == true_result_dict
print("OK")
# Out:
# {'unique': ['которое', 'детстве', 'постоянно', 'слышал', 'от', 'моей', 'мамы', 'мама', 'произносила', 'нежно', 'серьезно', 'словно', 'обозначало', 'что-то', 'столь', 'важное', 'неотъемлемое', 'любил', 'из-за', 'этого', 'делал', 'все', 'чтоб', 'услышать', 'как', 'чаще', 'вырос', 'понял', 'что', 'представляет', 'из', 'себя', 'чего-то', 'сверхъестественного', 'обозначает', 'какое-то', 'божество', 'произнести', 'по', 'разному', 'обычное', 'но', 'то', 'же', 'время', 'сильное', 'спасибо'], 'nonunique': ['это', 'слово', 'я', 'в', 'так', 'и', 'оно', 'его', 'можно', 'не', 'самое']}
# OK

# %% [markdown]
# # Задача 4
#
# Маша и Аня работают в отделе продаж нашего банка и продают Кредиты наличными. <br>
# Оформленные ими кредиты представлены в соответствующих словарях (сумма кредита, ставка, срок в годах)<br>
# Среди клиентов Маши и Ани найти клиентов и вывести на экран, у которых:<br>
# •	Совпадает ставка<br>
# •	Совпадает сумма кредита<br>
# •	Совпадает срок выплаты<br>
# •	Не совпадает сумма, но совпадает срок выплаты<br>
# •	Совпадает процентная ставка, но не совпадает сумма кредита.<br>
# Условие может, как выполниться, так и не выполниться (такое пересечение может быть пустым)<br>
#
# Выводить ВСЕ значения которые имеют совпадения.

# %%
masha_credits = {
        'Салтыков Иван': {
        'credit': 80000,
        'percent': 22.5,
        'period': 3
    },
        'Иванова Марина': {
        'credit': 240000,
        'percent': 20.8,
        'period': 5
    },
        'Жученко Виталий': {
        'credit': 35000,
        'percent': 19.4,
        'period': 2
    },
        'Петров Александр': {
        'credit': 100000,
        'percent': 27.9,
        'period': 3
    },
        'Краснов Антон': {
        'credit': 10000,
        'percent': 55.2,
        'period': 1
    },
        'Полено Елена': {
        'credit': 330000,
        'percent': 4.0,
        'period': 1
    },
}

ann_credits = {
        'Букин Геннадий': {
        'credit': 1000,
        'percent': 55.2,
        'period': 20
    },
        'Антонов Юрий': {
        'credit': 20000,
        'percent': 20.8,
        'period': 4
    },
        'Трененков Виталий': {
        'credit': 35000,
        'percent': 20.1,
        'period': 1
    },
        'Самоваров Павел': {
        'credit': 100000,
        'percent': 27.9,
        'period': 2
    },
        'Самсонов Владимир': {
        'credit': 76000,
        'percent': 11.9,
        'period': 4
    },
        'Антонина Антонина': {
        'credit': 1100000,
        'percent': 4.0,
        'period': 5
    },
        'Колованов Ярослав': {
        'credit': 25000,
        'percent': 22.2,
        'period': 2
    },
        'Чайкина Наталья': {
        'credit': 330000,
        'percent': 18.9,
        'period': 3
    },
}

# ваше решение тут
dct = {}
l=[]
st=set()  # Совпадает ставка
cr=set()  # Совпадает сумма кредита
sr=set()  # Совпадает срок выплаты
cs=set()  # Не совпадает сумма, но совпадает срок выплаты
rc=set()  # Совпадает процентная ставка, но не совпадает сумма кредита



dct.update(masha_credits)
dct.update(ann_credits)

for k, v in dct.items():
  d={}
  d['name']=k
  d.update(v)
  l.append(d)

n=len(l)

for i in range(n):
  for q in range(i+1, n):
      if l[i]['credit']==l[q]['credit']:
          cr.add(l[i]['credit'])
          #print('у клиентов:', l[i]['name'], 'и', l[q]['name'], 'совпадает сумма кредита =', l[i]['credit'])
      else:
          if l[i]['percent']==l[q]['percent']:
              rc.add(l[i]['percent'])
              #print('у клиентов:', l[i]['name'], 'и', l[q]['name'], 'Совпадает процентная ставка но не совпадает сумма =', l[i]['percent'], ',', 'но не совпадает сумма кредита.')
          
          if l[i]['period']==l[q]['period']:
              cs.add(l[i]['period'])
              #print('у клиентов:', l[i]['name'], 'и', l[q]['name'], 'Не совпадает сумма, но совпадает срок выплаты =', l[i]['period'])
        
        
      if l[i]['percent']==l[q]['percent']:
          st.add(l[i]['percent'])
          #print('у клиентов:', l[i]['name'], 'и', l[q]['name'], 'совпадает ставка по кредиту =', l[i]['percent'])
      
      if l[i]['period']==l[q]['period']:
          sr.add(l[i]['period'])
          #print('у клиентов:', l[i]['name'], 'и', l[q]['name'], 'Совпадает срок выплаты =', l[i]['period'])

d = {}      
d1 = {} 
d2 = {}
d3 = {}
d4 = {}


for i in st: # Совпадает ставка
  l1 = []
  d[i] = l1
  
  for q in l: 
      if i == q['percent']:
          l1.append(q['name'])
         
  print('"СОВПАДАЕТ СТАВКА"  У клиентов:', d[i], 'совпадает ставка по кредиту =', i,)
  
for i in cr: # Совпадает сумма кредита
  l1 = []
  d1[i] = l1
  
  for q in l: 
      if i == q['credit']:
          l1.append(q['name'])
         
  print('"СОВПАДАЕТ СУММА" У клиентов:', d1[i], 'совпадает сумма кредита =', i, )    
  
for i in sr: # Совпадает срок выплаты
  l1 = []
  d2[i] = l1
  
  for q in l: 
      if i == q['period']:
          l1.append(q['name'])
         
  print('"СОВПАДАЕТ СРОК ВЫПЛАТЫ" У клиентов:', d2[i], 'совпадает срок выплаты по кредиту =', i,)  
  
  
for i in cs: # Не совпадает сумма, но совпадает срок выплаты
  l1 = []
  d3[i] = l1
  
  for q in l: 
      if i == q['period']:
          l1.append(q['name'])
         
  print('"НЕ СОВПАДАЕТ СУММА, НО СОВПАДАЕТ СРОК" У клиентов:', d3[i], 'Не совпадает сумма, но совпадает срок выплаты =', i)  
  
  
for i in rc: # Совпадает процентная ставка, но не совпадает сумма кредита
  l1 = []
  d4[i] = l1
  
  for q in l: 
      if i == q['percent']:
          l1.append(q['name'])
         
  print('"СОВПАДАЕТ СТАВКА, НО НЕ СОВПАДАЕТ СУММА" У клиентов:', d4[i], 'Совпадает процентная ставка, но не совпадает сумма кредита =', i)
# Out:
# "СОВПАДАЕТ СТАВКА"  У клиентов: ['Петров Александр', 'Самоваров Павел'] совпадает ставка по кредиту = 27.9
# "СОВПАДАЕТ СТАВКА"  У клиентов: ['Иванова Марина', 'Антонов Юрий'] совпадает ставка по кредиту = 20.8
# "СОВПАДАЕТ СТАВКА"  У клиентов: ['Полено Елена', 'Антонина Антонина'] совпадает ставка по кредиту = 4.0
# "СОВПАДАЕТ СТАВКА"  У клиентов: ['Краснов Антон', 'Букин Геннадий'] совпадает ставка по кредиту = 55.2
# "СОВПАДАЕТ СУММА" У клиентов: ['Жученко Виталий', 'Трененков Виталий'] совпадает сумма кредита = 35000
# "СОВПАДАЕТ СУММА" У клиентов: ['Полено Елена', 'Чайкина Наталья'] совпадает сумма кредита = 330000
# "СОВПАДАЕТ СУММА" У клиентов: ['Петров Александр', 'Самоваров Павел'] совпадает сумма кредита = 100000
# "СОВПАДАЕТ СРОК ВЫПЛАТЫ" У клиентов: ['Краснов Антон', 'Полено Елена', 'Трененков Виталий'] совпадает срок выплаты по кредиту = 1
# "СОВПАДАЕТ СРОК ВЫПЛАТЫ" У клиентов: ['Жученко Виталий', 'Самоваров Павел', 'Колованов Ярослав'] совпадает срок выплаты по кредиту = 2
# "СОВПАДАЕТ СРОК ВЫПЛАТЫ" У клиентов: ['Салтыков Иван', 'Петров Александр', 'Чайкина Наталья'] совпадает срок выплаты по кредиту = 3
# "СОВПАДАЕТ СРОК ВЫПЛАТЫ" У клиентов: ['Антонов Юрий', 'Самсонов Владимир'] совпадает срок выплаты по кредиту = 4
# "СОВПАДАЕТ СРОК ВЫПЛАТЫ" У клиентов: ['Иванова Марина', 'Антонина Антонина'] совпадает срок выплаты по кредиту = 5
# "НЕ СОВПАДАЕТ СУММА, НО СОВПАДАЕТ СРОК" У клиентов: ['Краснов Антон', 'Полено Елена', 'Трененков Виталий'] Не совпадает сумма, но совпадает срок выплаты = 1
# "НЕ СОВПАДАЕТ СУММА, НО СОВПАДАЕТ СРОК" У клиентов: ['Жученко Виталий', 'Самоваров Павел', 'Колованов Ярослав'] Не совпадает сумма, но совпадает срок выплаты = 2
# "НЕ СОВПАДАЕТ СУММА, НО СОВПАДАЕТ СРОК" У клиентов: ['Салтыков Иван', 'Петров Александр', 'Чайкина Наталья'] Не совпадает сумма, но совпадает срок выплаты = 3
# "НЕ СОВПАДАЕТ СУММА, НО СОВПАДАЕТ СРОК" У клиентов: ['Антонов Юрий', 'Самсонов Владимир'] Не совпадает сумма, но совпадает срок выплаты = 4
# "НЕ СОВПАДАЕТ СУММА, НО СОВПАДАЕТ СРОК" У клиентов: ['Иванова Марина', 'Антонина Антонина'] Не совпадает сумма, но совпадает срок выплаты = 5
# "СОВПАДАЕТ СТАВКА, НО НЕ СОВПАДАЕТ СУММА" У клиентов: ['Иванова Марина', 'Антонов Юрий'] Совпадает процентная ставка, но не совпадает сумма кредита = 20.8
# "СОВПАДАЕТ СТАВКА, НО НЕ СОВПАДАЕТ СУММА" У клиентов: ['Полено Елена', 'Антонина Антонина'] Совпадает процентная ставка, но не совпадает сумма кредита = 4.0
# "СОВПАДАЕТ СТАВКА, НО НЕ СОВПАДАЕТ СУММА" У клиентов: ['Краснов Антон', 'Букин Геннадий'] Совпадает процентная ставка, но не совпадает сумма кредита = 55.2

# %% [markdown]
# # Задача 5
# Суть задачи в том, чтобы из англо-латинского словаря сделать латино-английский.
#
# Входные данные:<br>
# Даны строки (необходимо представить в виде словаря)
#
# apple - malum, pomum, popula<br>
# fruit - baca, bacca, popum<br>
# punishment - malum, multa<br>
#
# Выходные данные:<br>
# baca - fruit<br>
# bacca - fruit<br>
# malum - apple, punishment<br>
# multa - punishment<br>
# pomum - apple<br>
# popula - apple<br>
# popum - fruit<br>

# %%
s1 = 'apple - malum, pomum, popula'
s2 = 'fruit - baca, bacca, popum'
s3 = 'punishment - malum, multa'
s4 = [s1,s2,s3]
s5 = set()
dct = {}
dct2 = {}
l = []

for i in s4:
  i = i.replace(' ','')
  dct[i[:i.find('-')]] = i[i.find('-') + 1:].split(',')
 
print(dct)

for i in dct:
  for c in dct[i]:
    s5.add(c)

l = list(s5)
l.sort()

for i in l:
  dct2[i]=[]
  for c in dct:
    if i in dct[c]:
      dct2[i].append(c)

print(dct2)
# Out:
# {'apple': ['malum', 'pomum', 'popula'], 'fruit': ['baca', 'bacca', 'popum'], 'punishment': ['malum', 'multa']}
# {'baca': ['fruit'], 'bacca': ['fruit'], 'malum': ['apple', 'punishment'], 'multa': ['punishment'], 'pomum': ['apple'], 'popula': ['apple'], 'popum': ['fruit']}
